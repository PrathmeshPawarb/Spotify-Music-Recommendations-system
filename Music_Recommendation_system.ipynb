# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/dataset.csv', on_bad_lines='skip')
df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
df.drop(['Unnamed: 0','track_id'], axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
# Drop duplicate entries based on 'track_name'
df_no_duplicates = df.drop_duplicates(subset='track_name', keep='first')

# %%
df_no_duplicates
# Out:
#                        artists  \
# 0                  Gen Hoshino
# 1                 Ben Woodward
# 2       Ingrid Michaelson;ZAYN
# 3                 Kina Grannis
# 4             Chord Overstreet
# ...                        ...
# 113994          Lucas Cervetti
# 113995           Rainy Lullaby
# 113996           Rainy Lullaby
# 113997           Cesária Evora
# 113999           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113994                       Frecuencias Álmicas en 432hz
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# ...

# %%
df = df_no_duplicates

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#         index                 artists  \
# 0           0             Gen Hoshino
# 1           1            Ben Woodward
# 2           2  Ingrid Michaelson;ZAYN
# 3           3            Kina Grannis
# 4           4        Chord Overstreet
# ...       ...                     ...
# 73603  113994          Lucas Cervetti
# 73604  113995           Rainy Lullaby
# 73605  113996           Rainy Lullaby
# 73606  113997           Cesária Evora
# 73607  113999           Cesária Evora
#
#                                               album_name  \
# 0                                                 Comedy
# 1                                       Ghost (Acoustic)
# 2                                         To Begin Again
# 3      Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                Hold On
# ...                                                  ...
# 73603                       Frecuencias Álmicas en 432hz
# ...

# %%
df.drop(['index'], axis=1, inplace=True)
# Out:
# <ipython-input-12-6da47b56dfaf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['index'], axis=1, inplace=True)

# %%
df
# Out:
#                       artists  \
# 0                 Gen Hoshino
# 1                Ben Woodward
# 2      Ingrid Michaelson;ZAYN
# 3                Kina Grannis
# 4            Chord Overstreet
# ...                       ...
# 73603          Lucas Cervetti
# 73604           Rainy Lullaby
# 73605           Rainy Lullaby
# 73606           Cesária Evora
# 73607           Cesária Evora
#
#                                               album_name  \
# 0                                                 Comedy
# 1                                       Ghost (Acoustic)
# 2                                         To Begin Again
# 3      Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                Hold On
# ...                                                  ...
# 73603                       Frecuencias Álmicas en 432hz
# 73604  #mindfulness - Soft Rain for Mindful Meditatio...
# 73605  #mindfulness - Soft Rain for Mindful Meditatio...
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df['track_genre'].unique()
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
#        'anime', 'black-metal', 'bluegrass', 'blues', 'brazil',
#        'breakbeat', 'british', 'cantopop', 'chicago-house', 'children',
#        'chill', 'classical', 'club', 'comedy', 'country', 'dance',
#        'dancehall', 'death-metal', 'deep-house', 'detroit-techno',
#        'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm',
#        'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk',
#        'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
#        'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
#        'heavy-metal', 'hip-hop', 'honky-tonk', 'house', 'idm', 'indian',
#        'indie-pop', 'indie', 'industrial', 'iranian', 'j-dance', 'j-idol',
#        'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino',
#        'malay', 'mandopop', 'metal', 'metalcore', 'minimal-techno', 'mpb',
# ...

# %%
df['track_genre'].nunique()
# Out:
# 113

# %%
df['track_genre'].value_counts()
# Out:
# black-metal    981
# comedy         965
# afrobeat       945
# heavy-metal    944
# cantopop       935
#               ...
# reggae         142
# rock           116
# house           98
# indie           93
# reggaeton       56
# Name: track_genre, Length: 113, dtype: int64

# %%
df.describe()
# Out:
#          popularity   duration_ms  danceability        energy           key  \
# count  73608.000000  7.360800e+04  73608.000000  73608.000000  73608.000000
# mean      34.386493  2.321333e+05      0.558683      0.636944      5.283746
# std       19.193482  1.189979e+05      0.178512      0.258685      3.556254
# min        0.000000  8.586000e+03      0.000000      0.000000      0.000000
# 25%       21.000000  1.739305e+05      0.445000      0.457000      2.000000
# 50%       34.000000  2.158865e+05      0.573000      0.680000      5.000000
# 75%       48.000000  2.686000e+05      0.690000      0.859000      8.000000
# max      100.000000  5.237295e+06      0.985000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  73608.000000  73608.000000  73608.000000  73608.000000
# mean      -8.604242      0.633763      0.090341      0.331151
# std        5.319762      0.481779      0.119302      0.339816
# ...

# %%
df['track_genre'].nunique()
# Out:
# 113

# %%
df['track_genre'].value_counts()
# Out:
# black-metal    981
# comedy         965
# afrobeat       945
# heavy-metal    944
# cantopop       935
#               ...
# reggae         142
# rock           116
# house           98
# indie           93
# reggaeton       56
# Name: track_genre, Length: 113, dtype: int64

# %%
df
# Out:
#                       artists  \
# 0                 Gen Hoshino
# 1                Ben Woodward
# 2      Ingrid Michaelson;ZAYN
# 3                Kina Grannis
# 4            Chord Overstreet
# ...                       ...
# 73603          Lucas Cervetti
# 73604           Rainy Lullaby
# 73605           Rainy Lullaby
# 73606           Cesária Evora
# 73607           Cesária Evora
#
#                                               album_name  \
# 0                                                 Comedy
# 1                                       Ghost (Acoustic)
# 2                                         To Begin Again
# 3      Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                Hold On
# ...                                                  ...
# 73603                       Frecuencias Álmicas en 432hz
# 73604  #mindfulness - Soft Rain for Mindful Meditatio...
# 73605  #mindfulness - Soft Rain for Mindful Meditatio...
# ...

# %% [markdown]
# # visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Select relevant columns for visualization
selected_columns = ['popularity', 'duration_ms', 'danceability', 'energy', 'acousticness', 'instrumentalness', 'valence']

# Create a pairplot
sns.pairplot(df[selected_columns], height=2, kind='scatter', diag_kind='kde')
plt.show()

# %%
# Plot the distribution of Popularity
plt.figure(figsize=(10, 6))
sns.histplot(df['popularity'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Popularity')
plt.xlabel('Popularity')
plt.ylabel('Frequency')
plt.show()

# %%
# Count the occurrences of each unique track genre
genre_counts = df['track_genre'].value_counts()

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x=genre_counts.index, y=genre_counts.values, palette='viridis')
plt.title('Distribution of Unique Track Genres')
plt.xlabel('Track Genre')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
import matplotlib.pyplot as plt


top_genres = df.groupby('track_genre')['popularity'].mean().sort_values(ascending=False).head(30)

plt.figure(figsize=(12, 12))
plt.pie(top_genres, labels=top_genres.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Top 15 Track Genres by Mean Popularity')
plt.show()

# %%
# Choose the top N track genres based on average popularity
top_genres = df.groupby('track_genre')['popularity'].mean().sort_values(ascending=False).head(15).index
top_genres
# Out:
# Index(['pop-film', 'k-pop', 'pop', 'chill', 'metal', 'hip-hop', 'sad',
#        'latino', 'house', 'indian', 'singer-songwriter', 'grunge', 'piano',
#        'emo', 'edm'],
#       dtype='object', name='track_genre')

# %%
# Filter the DataFrame to include only the top genres
df_top_genres = df[df['track_genre'].isin(top_genres)]

# %%
# Create a bar plot for average popularity by track genre
plt.figure(figsize=(15, 5))
sns.barplot(x='popularity', y='track_genre',
            data=df_top_genres, estimator=lambda x: sum(x) / len(x),
            ci=None, order=df_top_genres.groupby('track_genre')['popularity'].mean().sort_values(ascending=False).index,
            palette='viridis')
plt.title('Average Popularity by Track Genre (Top 15)')
plt.xlabel('Average Popularity')
plt.ylabel('Track Genre')
plt.show()
# Out:
# <ipython-input-31-99e96a2f5c3a>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='popularity', y='track_genre',

# %%
plt.figure(figsize=(15,6))
plt.subplot(211)
sns.boxplot(x="track_genre", y="loudness", data=df_top_genres)
plt.subplot(212)
sns.boxplot(x="track_genre", y="speechiness", data=df_top_genres)
plt.show()

# %%
# Count the occurrences of explicit and non-explicit songs
explicit_counts = df['explicit'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(explicit_counts, labels=['Non-Explicit', 'Explicit'], autopct='%1.1f%%', startangle=90, colors=['skyblue', 'salmon'])
plt.title('Distribution of Explicit vs Non-Explicit Songs')
plt.show()

# %%
#Heatmap
# Convert the 'explicit' column to numeric for heatmap
df['explicit'] = df['explicit'].astype(int)

# Create a correlation matrix
correlation_matrix = df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Create a heatmap with the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)

# Display the plot
plt.show()
# Out:
# <ipython-input-34-7335637f324a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['explicit'] = df['explicit'].astype(int)
# <ipython-input-34-7335637f324a>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# #Model Building

# %%
df
# Out:
#                       artists  \
# 0                 Gen Hoshino
# 1                Ben Woodward
# 2      Ingrid Michaelson;ZAYN
# 3                Kina Grannis
# 4            Chord Overstreet
# ...                       ...
# 73603          Lucas Cervetti
# 73604           Rainy Lullaby
# 73605           Rainy Lullaby
# 73606           Cesária Evora
# 73607           Cesária Evora
#
#                                               album_name  \
# 0                                                 Comedy
# 1                                       Ghost (Acoustic)
# 2                                         To Begin Again
# 3      Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                Hold On
# ...                                                  ...
# 73603                       Frecuencias Álmicas en 432hz
# 73604  #mindfulness - Soft Rain for Mindful Meditatio...
# 73605  #mindfulness - Soft Rain for Mindful Meditatio...
# ...

# %%
# Standardize numerical features
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
# Drop non-numeric columns
df_numeric = df.select_dtypes(include=['float64', 'int64'])
df_numeric
# Out:
#        popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 0              73       230666         0         0.676  0.4610    1    -6.746
# 1              55       149610         0         0.420  0.1660    1   -17.235
# 2              57       210826         0         0.438  0.3590    0    -9.734
# 3              71       201933         0         0.266  0.0596    0   -18.515
# 4              82       198853         0         0.618  0.4430    2    -9.681
# ...           ...          ...       ...           ...     ...  ...       ...
# 73603          22       305454         0         0.331  0.1710    1   -15.668
# 73604          21       384999         0         0.172  0.2350    5   -16.393
# 73605          22       385000         0         0.174  0.1170    0   -18.318
# 73606          22       271466         0         0.629  0.3290    0   -10.895
# 73607          22       241826         0         0.526  0.4870    1   -10.204
#
# ...

# %%
# Standardize numerical features

df_numeric = pd.DataFrame(sc.fit_transform(df_numeric), columns=df_numeric.columns)
df_numeric
# Out:
#        popularity  duration_ms  explicit  danceability    energy       key  \
# 0        2.011817    -0.012331 -0.307637      0.657195 -0.680154 -1.204575
# 1        1.073992    -0.693490 -0.307637     -0.776889 -1.820547 -1.204575
# 2        1.178195    -0.179058 -0.307637     -0.676055 -1.074459 -1.485772
# 3        1.907614    -0.253790 -0.307637     -1.639581 -2.231861 -1.485772
# 4        2.480729    -0.279673 -0.307637      0.332285 -0.749737 -0.923378
# ...           ...          ...       ...           ...       ...       ...
# 73603   -0.645353     0.616155 -0.307637     -1.275458 -1.801218 -1.204575
# 73604   -0.697455     1.284617 -0.307637     -2.166158 -1.553811 -0.079789
# 73605   -0.645353     1.284625 -0.307637     -2.154955 -2.009968 -1.485772
# 73606   -0.645353     0.330535 -0.307637      0.393906 -1.190431 -1.485772
# 73607   -0.645353     0.081453 -0.307637     -0.183089 -0.579645 -1.204575
#
# ...

# %%
df_numeric = df_numeric.round(2)
df_numeric
# Out:
#        popularity  duration_ms  explicit  danceability  energy   key  \
# 0            2.01        -0.01     -0.31          0.66   -0.68 -1.20
# 1            1.07        -0.69     -0.31         -0.78   -1.82 -1.20
# 2            1.18        -0.18     -0.31         -0.68   -1.07 -1.49
# 3            1.91        -0.25     -0.31         -1.64   -2.23 -1.49
# 4            2.48        -0.28     -0.31          0.33   -0.75 -0.92
# ...           ...          ...       ...           ...     ...   ...
# 73603       -0.65         0.62     -0.31         -1.28   -1.80 -1.20
# 73604       -0.70         1.28     -0.31         -2.17   -1.55 -0.08
# 73605       -0.65         1.28     -0.31         -2.15   -2.01 -1.49
# 73606       -0.65         0.33     -0.31          0.39   -1.19 -1.49
# 73607       -0.65         0.08     -0.31         -0.18   -0.58 -1.20
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
from scipy.sparse import csr_matrix

# Convert the DataFrame to a sparse matrix
sparse_matrix = csr_matrix(df_numeric.values)

# %% [markdown]
# sparse matrices in recommendation systems provides advantages in terms of memory efficiency, computational speed, and scalability, making them well-suited for handling the inherent sparsity in user-item interaction data.

# %% [markdown]
# ## “Approximate Nearest Neighbors

# %%
# !pip install annoy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.5/647.5 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for annoy: filename=annoy-1.17.3-cp310-cp310-linux_x86_64.whl size=552449 sha256=7d57652b23313958b00ef442d09aa880bc9ee40f59af69a9eaec6d6564db7d16
#   Stored in directory: /root/.cache/pip/wheels/64/8a/da/f714bcf46c5efdcfcac0559e63370c21abe961c48e3992465a
# Successfully built annoy
# ...

# %%
from annoy import AnnoyIndex

# %% [markdown]
# Annoy stands for “Approximate Nearest Neighbors Oh Yeah” and was developed by Spotify's Research & Development team. It was specifically designed to efficiently handle approximate nearest neighbor searches, making it ideal for tasks like recommendation systems, search algorithms, and machine learning applications.

# %%
# Build Annoy Index
annoy_index = AnnoyIndex(sparse_matrix.shape[1], 'angular')
for i in range(sparse_matrix.shape[0]):
    vector = sparse_matrix.getrow(i).toarray().flatten()
    annoy_index.add_item(i, vector)

# %%
# Build the index
annoy_index.build(75)         # here The argument 75 here represents the number of trees in the index
# Out:
# True

# %%
def recommend_tracks_annoy(track_name, annoy_index, df, num_recommendations=5):
    track_index = df[df['track_name'] == track_name].index[0]
    num_recommendations = min(num_recommendations, annoy_index.get_n_items())  # Limit recommendations to index size
    related_tracks_indices = annoy_index.get_nns_by_item(track_index, num_recommendations)
    recommendations = df.iloc[related_tracks_indices][['track_name', 'artists','track_genre','popularity']]
    return recommendations

# %% [markdown]
# ## Example: Get recommendations for a track

# %%
track_name_to_recommend = 'Friends'
recommendations_annoy = recommend_tracks_annoy(track_name_to_recommend, annoy_index, df)
print(f"Recommendations for track '{track_name_to_recommend}':\n{recommendations_annoy}")
# Out:
# Recommendations for track 'Friends':
#            track_name              artists  track_genre  popularity
# 1651          Friends    Jor'dan Armstrong     afrobeat          18
# 54499  Anders ist gut             Michelle        party          25
# 47470         Jacuzzi       Greeicy;Anitta        latin           0
# 59619    Amar y Vivír  Los Pasteles Verdes  rock-n-roll          32
# 22999     Don't Shoot          Steel Pulse          dub          26

# %% [markdown]
# if isinstance(recommendations_annoy, str):
#     print(recommendations_annoy)
# else:
#     print(f"Recommendations for track '{track_name_to_recommend}':\n")
#     print(tabulate(recommendations_annoy, headers='keys', tablefmt='pretty'))

# %%
# Print recommendations using tabulate
from tabulate import tabulate

track_name_to_recommend = "Friends"
recommendations_annoy = recommend_tracks_annoy(track_name_to_recommend, annoy_index, df)
print(f"Recommendations for track '{track_name_to_recommend}':\n")
print(tabulate(recommendations_annoy, headers='keys', tablefmt='pretty'))
# Out:
# Recommendations for track 'Friends':
#
# +-------+----------------+---------------------+-------------+------------+
# |       |   track_name   |       artists       | track_genre | popularity |
# +-------+----------------+---------------------+-------------+------------+
# | 1651  |    Friends     |  Jor'dan Armstrong  |  afrobeat   |     18     |
# | 54499 | Anders ist gut |      Michelle       |    party    |     25     |
# | 47470 |    Jacuzzi     |   Greeicy;Anitta    |    latin    |     0      |
# | 59619 |  Amar y Vivír  | Los Pasteles Verdes | rock-n-roll |     32     |
# | 22999 |  Don't Shoot   |     Steel Pulse     |     dub     |     26     |
# +-------+----------------+---------------------+-------------+------------+

# %% [markdown]
# ## download processed dataset

# %%
df.to_csv('spotify_tracks')
